# %%
path = 'C:/Users/김서윤/Documents/2020 2학기 강의/응용시계열분석(임미영)/Python 실습/AirPassengers (2).csv'

# %%
import pandas as pd
import numpy as np

import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
rcParams['figure.figsize'] = 15, 6

air_passengers = pd.read_csv(path, header = 0, parse_dates = [0],
                             names = ['Month', 'Passengers'], index_col = 0)
print('data shape:', air_passengers.shape)
# Out:
# data shape: (144, 1)

# %%
#assert False #해당 부분까지만 실행시키는 기능
#assert a==1 #a==1일 경우 넘어가고, 그게 아니면 이 부분에서 멈춘다
#검증을 위해 사용함

##log return
# log transformation
log_air_passengers = np.log(air_passengers.Passengers)
print(log_air_passengers[1:5])

# differencing 
log_air_passengers_diff = log_air_passengers - log_air_passengers.shift()

log_air_passengers_diff.dropna(inplace=True) #결측치 있으면 drop
print(log_air_passengers_diff[1:5])
# Out:
# Month
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
# Name: Passengers, dtype: float64
# Month
# 1949-03-01    0.112117
# 1949-04-01   -0.022990
# 1949-05-01   -0.064022
# 1949-06-01    0.109484
# Name: Passengers, dtype: float64

# %%
# get acf & pacf
lag_acf = acf(log_air_passengers_diff.values, nlags = 15,fft=False)
lag_pacf = pacf(log_air_passengers_diff.values, nlags = 15)

print('lag_acf shape:', lag_acf.shape)
print(lag_acf[:5])

print('lag_pacf shape:', lag_pacf.shape)
print(lag_pacf[:5])
#첫번째 값이 1임.
# Out:
# lag_acf shape: (16,)
# [ 1.          0.19975134 -0.12010433 -0.15077204 -0.32207432]
# lag_pacf shape: (16,)
# [ 1.          0.20115804 -0.16911569 -0.09799183 -0.32038128]

# %%
def plot_acfs():
    plt.subplot(121) 
    plt.plot(lag_acf)
    plt.axhline(y=0,linestyle='--')
    plt.axhline(y=-1.96/np.sqrt(len(log_air_passengers_diff)),linestyle='--')
    plt.axhline(y=1.96/np.sqrt(len(log_air_passengers_diff)),linestyle='--')

    plt.subplot(122) 
    plt.plot(lag_pacf)
    plt.axhline(y=0,linestyle='--')
    plt.axhline(y=-1.96/np.sqrt(len(log_air_passengers_diff)),linestyle='--') #유의수준 적어줌
    plt.axhline(y=1.96/np.sqrt(len(log_air_passengers_diff)),linestyle='--') 
    plt.show()

# %%
plot_acfs() #acf / pacf
#acf: 1, 4, 8에서 넘어가고 12에서 많이 넘어감. 시즈널 데이터.
#pacf: 2,4,8에서 넘아감. acf와 비슷한 양상

# %%
def plot_model(values, color='black'):
    plt.plot(values, color=color)
    #plt.title('RSS: %.4f'% sum((values-log_air_passengers_diff)**2))

# %%
plt.plot(log_air_passengers_diff)

# %%
# ar model, fix the order as 1 according to the pacf
model = ARIMA(log_air_passengers, order=(2, 1, 0))
results_AR = model.fit(disp=-1)
print('plotting ar...', 'AR RSS: %.4f'%
      sum((results_AR.fittedvalues-log_air_passengers_diff)**2))#오차값: 1.5정도
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# plotting ar... AR RSS: 1.5023

# %%
plot_model(results_AR.fittedvalues, color='red')

# %%
plt.plot(log_air_passengers_diff)
plot_model(results_AR.fittedvalues, color='red')
#AR 모델만 사용했기 때문에 차이가 많이 남

# %%
# ma model, fix
model = ARIMA(log_air_passengers, order=(0, 1, 2))  #MA order가 1일때보다 2일때 오차값이 더 낮음. 육안으로 후보를 찾고 검증해보자
results_MA = model.fit(disp=-1)
print('plotting ma...', 'MA RSS: %.4f'% sum((results_MA.fittedvalues-log_air_passengers_diff)**2))
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# plotting ma... MA RSS: 1.4721

# %%
plot_model(results_MA.fittedvalues, color='pink')

# %%
plt.plot(log_air_passengers_diff)
plot_model(results_AR.fittedvalues, color='red')
plot_model(results_MA.fittedvalues, color='pink') #얘도 잘 피팅되진 않음

# %%
# ARIMA model
model = ARIMA(log_air_passengers, order=(2, 1, 2))  
results_ARIMA = model.fit(disp=-1)
print('plotting ARIMA...', 'ARIMA RSS: %.4f'% sum((results_ARIMA.fittedvalues-log_air_passengers_diff)**2))
#잔차가 가장 낮다
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# plotting ARIMA... ARIMA RSS: 1.0292

# %%
plot_model(results_ARIMA.fittedvalues, color='black')
#plt.show()

# %%
plt.plot(log_air_passengers_diff)
plot_model(results_AR.fittedvalues, color='red')
plot_model(results_MA.fittedvalues, color='pink') #얘도 잘 피팅되진 않음
plot_model(results_ARIMA.fittedvalues, color='black') #가장 잘 모델링 됨
#plt.show()

# %%
# predictions 
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)#피팅된 값을 복사
print(predictions_ARIMA_diff.head())
# Out:
# Month
# 1949-02-01    0.009580
# 1949-03-01    0.017491
# 1949-04-01    0.027670
# 1949-05-01   -0.004521
# 1949-06-01   -0.023889
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())
#차분을 해 트렌드를 없앴었는데, 이걸 다시 누적합으로 더해줌
# Out:
# Month
# 1949-02-01    0.009580
# 1949-03-01    0.027071
# 1949-04-01    0.054742
# 1949-05-01    0.050221
# 1949-06-01    0.026331
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(log_air_passengers.iloc[0],
                                  index=log_air_passengers.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.728079
# 1949-03-01    4.745570
# 1949-04-01    4.773241
# 1949-05-01    4.768720
# dtype: float64

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log) #로그값에 지수 씌워서 원래대로 되돌림

# %%
plt.plot(air_passengers)# 원래 데이터

# %%
plt.plot(predictions_ARIMA) #예측한 값
#plt.show()

# %%
plt.plot(air_passengers)# 원래 데이터
plt.plot(predictions_ARIMA) #예측한 값
