# %%
import numpy as np
import pandas as pd
from dataclasses import dataclass
import queue

# %%
def taxi_id_num(num_taxis):
    arr = np.arange(num_taxis)
    np.random.shuffle(arr)
    for i in range(num_taxis):
        yield arr[i]
ids = taxi_id_num(10)
print(next(ids))
print(next(ids))
print(next(ids))
# Out:
# 7
# 1
# 3

# %%
def shift_info():
    start_times_and_freqs = [(0,8), (8, 30), (16, 15)]
    indices = np.arange(len(start_times_and_freqs))

    while True:
        idx = np.random.choice(indices, p=[0.25,0.5, 0.25])
        # print(idx)
        start = start_times_and_freqs[idx]
        # print(start)
        yield (start[0], start[0]+7.5, start[1])


print(next(shift_info()))
# Out:
# (8, 15.5, 30)

# %%
def taxi_process(taxi_id_generator, shift_info_generator):
    taxi_id = next(taxi_id_generator)
    shift_start, shift_end, shift_mean_trips = next(shift_info_generator)

    actural_trips = round(np.random.normal(loc=shift_mean_trips, scale=2))

    avg_trip_time = 6.5 /shift_mean_trips *60
    #convert mean trip time to minutes
    btw_events_time = 1.0 /(shift_mean_trips-1) *60

    time = shift_start
    yield TimePoint(taxi_id, 'start shift', time)
    deltaT = np.random.poisson(btw_events_time)
    time += deltaT
    for i in range(actural_trips):
        yield TimePoint(taxi_id, 'pick up', time)

        deltaT = np.random.poisson(avg_trip_time)/ 60
        time += deltaT
        yield TimePoint(taxi_id, 'drop off', time)

        deltaT = np.random.poisson(btw_events_time) /60
        time += deltaT

    deltaT = np.random.poisson(btw_events_time) /60
    time += deltaT
    yield TimePoint(taxi_id, 'end_shift', time )

# %%
@dataclass
class TimePoint:
    taxi_id: int
    name: str
    time: float

    def __lt__(self, other):
        return self.time <other.time

class Simulator:
    def _prepare_run(self):
        for t in self._taxis:
            while True:
                try:
                    e = next(t)
                    self._time_points.put(e)
                except:
                    break

    def run(self):
        sim_time = 0
        while sim_time <24:
            if self._time_points.empty():
                break
            p = self._time_points.get()
            sim_time = p.time
            print(p)

    def __init__(self, num_taxis):
        self._time_points = queue.PriorityQueue()
        taxi_id_generator = taxi_id_num(num_taxis)
        shift_info_generator = shift_info()
        self._taxis = [taxi_process(taxi_id_generator, shift_info_generator) for i in range(num_taxis)]

        self._prepare_run()

# %%
sim = Simulator(10) #taxi 개수
sim.run()
# Out:
# TimePoint(taxi_id=6, name='start shift', time=0)
# TimePoint(taxi_id=8, name='start shift', time=0)
# TimePoint(taxi_id=9, name='start shift', time=0)
# TimePoint(taxi_id=1, name='start shift', time=8)
# TimePoint(taxi_id=2, name='start shift', time=8)
# TimePoint(taxi_id=3, name='start shift', time=8)
# TimePoint(taxi_id=7, name='start shift', time=8)
# TimePoint(taxi_id=5, name='start shift', time=8)
# TimePoint(taxi_id=4, name='start shift', time=8)
# TimePoint(taxi_id=2, name='pick up', time=9)
# TimePoint(taxi_id=9, name='pick up', time=9)
# TimePoint(taxi_id=4, name='pick up', time=9)
# TimePoint(taxi_id=2, name='drop off', time=9.233333333333333)
# TimePoint(taxi_id=4, name='drop off', time=9.25)
# TimePoint(taxi_id=2, name='pick up', time=9.266666666666666)
# TimePoint(taxi_id=4, name='pick up', time=9.266666666666667)
# TimePoint(taxi_id=4, name='drop off', time=9.450000000000001)
# TimePoint(taxi_id=4, name='pick up', time=9.500000000000002)
# TimePoint(taxi_id=2, name='drop off', time=9.566666666666666)
# TimePoint(taxi_id=2, name='pick up', time=9.6)
# TimePoint(taxi_id=9, name='drop off', time=9.6)
# TimePoint(taxi_id=2, name='drop off', time=9.716666666666667)
# TimePoint(taxi_id=9, name='pick up', time=9.75)
# TimePoint(taxi_id=2, name='pick up', time=9.783333333333333)
# TimePoint(taxi_id=4, name='drop off', time=9.783333333333335)
# TimePoint(taxi_id=4, name='pick up', time=9.800000000000002)
# TimePoint(taxi_id=2, name='drop off', time=9.95)
# TimePoint(taxi_id=2, name='pick up', time=9.983333333333333)
# TimePoint(taxi_id=8, name='pick up', time=10)
# TimePoint(taxi_id=1, name='pick up', time=10)
# TimePoint(taxi_id=7, name='pick up', time=10)
# TimePoint(taxi_id=4, name='drop off', time=10.000000000000002)
# TimePoint(taxi_id=4, name='pick up', time=10.01666666666667)
# TimePoint(taxi_id=1, name='drop off', time=10.166666666666666)
# TimePoint(taxi_id=4, name='drop off', time=10.183333333333335)
# TimePoint(taxi_id=1, name='pick up', time=10.2)
# TimePoint(taxi_id=2, name='drop off', time=10.216666666666665)
# TimePoint(taxi_id=4, name='pick up', time=10.216666666666669)
# TimePoint(taxi_id=2, name='pick up', time=10.249999999999998)
# TimePoint(taxi_id=7, name='drop off', time=10.25)
# TimePoint(taxi_id=7, name='pick up', time=10.25)
# TimePoint(taxi_id=1, name='drop off', time=10.35)
# TimePoint(taxi_id=1, name='pick up', time=10.433333333333334)
# TimePoint(taxi_id=4, name='drop off', time=10.466666666666669)
# TimePoint(taxi_id=9, name='drop off', time=10.483333333333333)
# TimePoint(taxi_id=4, name='pick up', time=10.500000000000002)
# TimePoint(taxi_id=2, name='drop off', time=10.516666666666666)
# TimePoint(taxi_id=7, name='pick up', time=10.516666666666667)
# TimePoint(taxi_id=7, name='drop off', time=10.516666666666667)
# TimePoint(taxi_id=2, name='pick up', time=10.566666666666666)
# TimePoint(taxi_id=1, name='drop off', time=10.6)
# TimePoint(taxi_id=1, name='pick up', time=10.616666666666667)
# TimePoint(taxi_id=4, name='drop off', time=10.683333333333335)
# TimePoint(taxi_id=9, name='pick up', time=10.7)
# TimePoint(taxi_id=7, name='drop off', time=10.700000000000001)
# TimePoint(taxi_id=4, name='pick up', time=10.733333333333336)
# TimePoint(taxi_id=7, name='pick up', time=10.750000000000002)
# TimePoint(taxi_id=1, name='drop off', time=10.783333333333333)
# TimePoint(taxi_id=2, name='drop off', time=10.816666666666666)
# TimePoint(taxi_id=8, name='drop off', time=10.833333333333334)
# TimePoint(taxi_id=2, name='pick up', time=10.85)
# TimePoint(taxi_id=1, name='pick up', time=10.85)
# TimePoint(taxi_id=8, name='pick up', time=10.933333333333334)
# TimePoint(taxi_id=1, name='drop off', time=10.983333333333333)
# TimePoint(taxi_id=1, name='pick up', time=11.0)
# TimePoint(taxi_id=6, name='pick up', time=11)
# TimePoint(taxi_id=7, name='drop off', time=11.01666666666667)
# TimePoint(taxi_id=7, name='pick up', time=11.033333333333337)
# TimePoint(taxi_id=4, name='drop off', time=11.06666666666667)
# TimePoint(taxi_id=2, name='drop off', time=11.1)
# TimePoint(taxi_id=4, name='pick up', time=11.100000000000003)
# TimePoint(taxi_id=2, name='pick up', time=11.133333333333333)
# TimePoint(taxi_id=1, name='drop off', time=11.2)
# TimePoint(taxi_id=7, name='drop off', time=11.200000000000003)
# TimePoint(taxi_id=7, name='pick up', time=11.200000000000003)
# TimePoint(taxi_id=4, name='pick up', time=11.250000000000004)
# TimePoint(taxi_id=4, name='drop off', time=11.250000000000004)
# TimePoint(taxi_id=1, name='pick up', time=11.266666666666666)
# TimePoint(taxi_id=7, name='drop off', time=11.366666666666669)
# TimePoint(taxi_id=1, name='pick up', time=11.383333333333333)
# TimePoint(taxi_id=1, name='drop off', time=11.383333333333333)
# TimePoint(taxi_id=7, name='pick up', time=11.383333333333336)
# TimePoint(taxi_id=2, name='pick up', time=11.4)
# TimePoint(taxi_id=2, name='drop off', time=11.4)
# TimePoint(taxi_id=9, name='drop off', time=11.416666666666666)
# TimePoint(taxi_id=4, name='drop off', time=11.46666666666667)
# TimePoint(taxi_id=4, name='pick up', time=11.483333333333338)
# TimePoint(taxi_id=2, name='drop off', time=11.55)
# TimePoint(taxi_id=9, name='pick up', time=11.566666666666666)
# TimePoint(taxi_id=2, name='pick up', time=11.566666666666668)
# TimePoint(taxi_id=1, name='drop off', time=11.65)
# TimePoint(taxi_id=7, name='drop off', time=11.650000000000004)
# TimePoint(taxi_id=1, name='pick up', time=11.666666666666668)
# TimePoint(taxi_id=7, name='pick up', time=11.683333333333337)
# TimePoint(taxi_id=4, name='drop off', time=11.71666666666667)
# TimePoint(taxi_id=4, name='pick up', time=11.733333333333338)
# TimePoint(taxi_id=6, name='drop off', time=11.766666666666667)
# TimePoint(taxi_id=2, name='drop off', time=11.850000000000001)
# TimePoint(taxi_id=8, name='drop off', time=11.866666666666667)
# TimePoint(taxi_id=6, name='pick up', time=11.866666666666667)
# TimePoint(taxi_id=2, name='pick up', time=11.866666666666669)
# TimePoint(taxi_id=7, name='drop off', time=11.86666666666667)
# TimePoint(taxi_id=7, name='pick up', time=11.900000000000004)
# TimePoint(taxi_id=1, name='drop off', time=11.916666666666668)
# TimePoint(taxi_id=4, name='drop off', time=11.916666666666671)
# TimePoint(taxi_id=1, name='pick up', time=11.950000000000001)
# TimePoint(taxi_id=4, name='pick up', time=11.950000000000005)
# TimePoint(taxi_id=3, name='pick up', time=12)
# TimePoint(taxi_id=8, name='pick up', time=12.016666666666667)
# TimePoint(taxi_id=7, name='drop off', time=12.016666666666671)
# TimePoint(taxi_id=7, name='pick up', time=12.016666666666671)
# TimePoint(taxi_id=2, name='drop off', time=12.100000000000001)
# TimePoint(taxi_id=2, name='pick up', time=12.133333333333335)
# TimePoint(taxi_id=1, name='drop off', time=12.133333333333335)
# TimePoint(taxi_id=1, name='pick up', time=12.150000000000002)
# TimePoint(taxi_id=7, name='drop off', time=12.183333333333337)
# TimePoint(taxi_id=7, name='pick up', time=12.200000000000005)
# TimePoint(taxi_id=3, name='drop off', time=12.233333333333333)
# TimePoint(taxi_id=4, name='drop off', time=12.250000000000005)
# TimePoint(taxi_id=3, name='pick up', time=12.266666666666666)
# TimePoint(taxi_id=2, name='drop off', time=12.283333333333335)
# TimePoint(taxi_id=4, name='pick up', time=12.300000000000006)
# TimePoint(taxi_id=2, name='pick up', time=12.316666666666668)
# TimePoint(taxi_id=9, name='drop off', time=12.35)
# TimePoint(taxi_id=7, name='drop off', time=12.350000000000005)
# TimePoint(taxi_id=7, name='pick up', time=12.366666666666672)
# TimePoint(taxi_id=3, name='drop off', time=12.399999999999999)
# TimePoint(taxi_id=9, name='pick up', time=12.433333333333334)
# TimePoint(taxi_id=1, name='drop off', time=12.433333333333335)
# TimePoint(taxi_id=3, name='pick up', time=12.466666666666665)
# TimePoint(taxi_id=1, name='pick up', time=12.550000000000002)
# TimePoint(taxi_id=4, name='drop off', time=12.550000000000006)
# TimePoint(taxi_id=2, name='drop off', time=12.566666666666668)
# TimePoint(taxi_id=4, name='pick up', time=12.566666666666674)
# TimePoint(taxi_id=2, name='pick up', time=12.666666666666668)
# TimePoint(taxi_id=7, name='pick up', time=12.683333333333339)
# TimePoint(taxi_id=7, name='drop off', time=12.683333333333339)
# TimePoint(taxi_id=1, name='drop off', time=12.716666666666669)
# TimePoint(taxi_id=1, name='pick up', time=12.716666666666669)
# TimePoint(taxi_id=3, name='drop off', time=12.749999999999998)
# TimePoint(taxi_id=3, name='pick up', time=12.766666666666666)
# TimePoint(taxi_id=8, name='drop off', time=12.766666666666667)
# TimePoint(taxi_id=7, name='drop off', time=12.783333333333339)
# TimePoint(taxi_id=6, name='drop off', time=12.8)
# TimePoint(taxi_id=7, name='pick up', time=12.83333333333334)
# TimePoint(taxi_id=4, name='drop off', time=12.833333333333341)
# TimePoint(taxi_id=4, name='pick up', time=12.850000000000009)
# TimePoint(taxi_id=8, name='pick up', time=12.866666666666667)
# TimePoint(taxi_id=2, name='drop off', time=12.883333333333335)
# TimePoint(taxi_id=6, name='pick up', time=12.883333333333335)
# TimePoint(taxi_id=2, name='pick up', time=12.933333333333335)
# TimePoint(taxi_id=1, name='pick up', time=12.933333333333335)
# TimePoint(taxi_id=1, name='drop off', time=12.933333333333335)
# TimePoint(taxi_id=3, name='drop off', time=12.999999999999998)
# TimePoint(taxi_id=5, name='pick up', time=13)
# TimePoint(taxi_id=3, name='pick up', time=13.016666666666666)
# TimePoint(taxi_id=4, name='drop off', time=13.016666666666675)
# TimePoint(taxi_id=7, name='drop off', time=13.033333333333339)
# TimePoint(taxi_id=4, name='pick up', time=13.033333333333342)
# TimePoint(taxi_id=7, name='pick up', time=13.08333333333334)
# TimePoint(taxi_id=2, name='drop off', time=13.100000000000001)
# TimePoint(taxi_id=2, name='pick up', time=13.166666666666668)
# TimePoint(taxi_id=4, name='drop off', time=13.200000000000008)
# TimePoint(taxi_id=1, name='drop off', time=13.216666666666669)
# TimePoint(taxi_id=1, name='pick up', time=13.250000000000002)
# TimePoint(taxi_id=4, name='pick up', time=13.250000000000009)
# TimePoint(taxi_id=9, name='drop off', time=13.283333333333333)
# TimePoint(taxi_id=5, name='drop off', time=13.3)
# TimePoint(taxi_id=3, name='drop off', time=13.333333333333332)
# TimePoint(taxi_id=3, name='pick up', time=13.35)
# TimePoint(taxi_id=5, name='pick up', time=13.366666666666667)
# TimePoint(taxi_id=7, name='drop off', time=13.366666666666672)
# TimePoint(taxi_id=7, name='pick up', time=13.38333333333334)
# TimePoint(taxi_id=2, name='pick up', time=13.416666666666668)
# TimePoint(taxi_id=2, name='drop off', time=13.416666666666668)
# TimePoint(taxi_id=1, name='drop off', time=13.533333333333335)
# TimePoint(taxi_id=1, name='pick up', time=13.550000000000002)
# TimePoint(taxi_id=5, name='drop off', time=13.583333333333334)
# TimePoint(taxi_id=7, name='drop off', time=13.58333333333334)
# TimePoint(taxi_id=3, name='drop off', time=13.616666666666667)
# TimePoint(taxi_id=5, name='pick up', time=13.616666666666667)
# TimePoint(taxi_id=4, name='drop off', time=13.616666666666676)
# TimePoint(taxi_id=9, name='end_shift', time=13.633333333333333)
# TimePoint(taxi_id=7, name='pick up', time=13.63333333333334)
# TimePoint(taxi_id=8, name='drop off', time=13.65)
# TimePoint(taxi_id=3, name='pick up', time=13.65)
# TimePoint(taxi_id=2, name='drop off', time=13.683333333333335)
# TimePoint(taxi_id=4, name='pick up', time=13.70000000000001)
# TimePoint(taxi_id=5, name='drop off', time=13.733333333333334)
# TimePoint(taxi_id=5, name='pick up', time=13.766666666666667)
# TimePoint(taxi_id=7, name='drop off', time=13.78333333333334)
# TimePoint(taxi_id=2, name='pick up', time=13.800000000000002)
# TimePoint(taxi_id=7, name='pick up', time=13.800000000000008)
# TimePoint(taxi_id=1, name='drop off', time=13.81666666666667)
# TimePoint(taxi_id=8, name='pick up', time=13.85)
# TimePoint(taxi_id=5, name='drop off', time=13.883333333333335)
# TimePoint(taxi_id=1, name='pick up', time=13.883333333333336)
# TimePoint(taxi_id=7, name='drop off', time=13.883333333333342)
# TimePoint(taxi_id=3, name='pick up', time=13.9)
# TimePoint(taxi_id=3, name='drop off', time=13.9)
# TimePoint(taxi_id=5, name='pick up', time=13.900000000000002)
# TimePoint(taxi_id=4, name='pick up', time=13.916666666666677)
# TimePoint(taxi_id=4, name='drop off', time=13.916666666666677)
# TimePoint(taxi_id=6, name='drop off', time=13.933333333333335)
# TimePoint(taxi_id=7, name='pick up', time=13.966666666666676)
# TimePoint(taxi_id=2, name='drop off', time=14.01666666666667)
# TimePoint(taxi_id=6, name='pick up', time=14.066666666666668)
# TimePoint(taxi_id=2, name='pick up', time=14.083333333333336)
# TimePoint(taxi_id=4, name='drop off', time=14.083333333333343)
# TimePoint(taxi_id=1, name='drop off', time=14.100000000000003)
# TimePoint(taxi_id=4, name='pick up', time=14.116666666666676)
# TimePoint(taxi_id=1, name='pick up', time=14.133333333333336)
# TimePoint(taxi_id=7, name='pick up', time=14.166666666666675)
# TimePoint(taxi_id=7, name='drop off', time=14.166666666666675)
# TimePoint(taxi_id=5, name='drop off', time=14.200000000000003)
# TimePoint(taxi_id=3, name='drop off', time=14.25)
# TimePoint(taxi_id=5, name='pick up', time=14.250000000000004)
# TimePoint(taxi_id=3, name='pick up', time=14.3)
# TimePoint(taxi_id=1, name='drop off', time=14.300000000000002)
# TimePoint(taxi_id=7, name='drop off', time=14.300000000000008)
# TimePoint(taxi_id=4, name='pick up', time=14.30000000000001)
# TimePoint(taxi_id=4, name='drop off', time=14.30000000000001)
# TimePoint(taxi_id=7, name='pick up', time=14.333333333333341)
# TimePoint(taxi_id=2, name='drop off', time=14.383333333333336)
# TimePoint(taxi_id=1, name='pick up', time=14.383333333333336)
# TimePoint(taxi_id=5, name='drop off', time=14.400000000000004)
# TimePoint(taxi_id=3, name='drop off', time=14.433333333333334)
# TimePoint(taxi_id=2, name='pick up', time=14.450000000000003)
# TimePoint(taxi_id=5, name='pick up', time=14.450000000000005)
# TimePoint(taxi_id=3, name='pick up', time=14.483333333333334)
# TimePoint(taxi_id=4, name='drop off', time=14.516666666666676)
# TimePoint(taxi_id=4, name='pick up', time=14.566666666666677)
# TimePoint(taxi_id=8, name='drop off', time=14.616666666666667)
# TimePoint(taxi_id=5, name='drop off', time=14.666666666666671)
# TimePoint(taxi_id=4, name='drop off', time=14.683333333333344)
# TimePoint(taxi_id=3, name='drop off', time=14.700000000000001)
# TimePoint(taxi_id=1, name='drop off', time=14.700000000000003)
# TimePoint(taxi_id=2, name='pick up', time=14.700000000000003)
# TimePoint(taxi_id=2, name='drop off', time=14.700000000000003)
# TimePoint(taxi_id=7, name='pick up', time=14.700000000000008)
# TimePoint(taxi_id=7, name='drop off', time=14.700000000000008)
# TimePoint(taxi_id=4, name='pick up', time=14.700000000000012)
# TimePoint(taxi_id=3, name='pick up', time=14.733333333333334)
# TimePoint(taxi_id=8, name='pick up', time=14.75)
# TimePoint(taxi_id=1, name='pick up', time=14.750000000000004)
# TimePoint(taxi_id=5, name='pick up', time=14.750000000000005)
# TimePoint(taxi_id=7, name='drop off', time=14.850000000000009)
# TimePoint(taxi_id=7, name='pick up', time=14.866666666666676)
# TimePoint(taxi_id=2, name='drop off', time=14.883333333333336)
# TimePoint(taxi_id=1, name='drop off', time=14.900000000000004)
# TimePoint(taxi_id=2, name='pick up', time=14.900000000000004)
# TimePoint(taxi_id=6, name='drop off', time=14.916666666666668)
# TimePoint(taxi_id=1, name='pick up', time=14.916666666666671)
# TimePoint(taxi_id=4, name='drop off', time=14.983333333333345)
# TimePoint(taxi_id=5, name='drop off', time=15.000000000000005)
# TimePoint(taxi_id=4, name='pick up', time=15.000000000000012)
# TimePoint(taxi_id=3, name='drop off', time=15.016666666666667)
# TimePoint(taxi_id=3, name='pick up', time=15.033333333333335)
# TimePoint(taxi_id=6, name='pick up', time=15.05)
# TimePoint(taxi_id=5, name='pick up', time=15.050000000000006)
# TimePoint(taxi_id=1, name='drop off', time=15.066666666666672)
# TimePoint(taxi_id=2, name='drop off', time=15.083333333333337)
# TimePoint(taxi_id=1, name='pick up', time=15.08333333333334)
# TimePoint(taxi_id=7, name='drop off', time=15.083333333333343)
# TimePoint(taxi_id=2, name='pick up', time=15.100000000000005)
# TimePoint(taxi_id=7, name='pick up', time=15.116666666666676)
# TimePoint(taxi_id=4, name='drop off', time=15.183333333333346)
# TimePoint(taxi_id=4, name='pick up', time=15.183333333333346)
# TimePoint(taxi_id=3, name='drop off', time=15.233333333333334)
# TimePoint(taxi_id=5, name='drop off', time=15.250000000000005)
# TimePoint(taxi_id=1, name='drop off', time=15.250000000000005)
# TimePoint(taxi_id=2, name='drop off', time=15.250000000000005)
# TimePoint(taxi_id=3, name='pick up', time=15.266666666666667)
# TimePoint(taxi_id=1, name='pick up', time=15.266666666666673)
# TimePoint(taxi_id=2, name='pick up', time=15.266666666666673)
# TimePoint(taxi_id=5, name='pick up', time=15.283333333333339)
# TimePoint(taxi_id=7, name='drop off', time=15.283333333333342)
# TimePoint(taxi_id=7, name='pick up', time=15.333333333333343)
# TimePoint(taxi_id=1, name='drop off', time=15.38333333333334)
# TimePoint(taxi_id=1, name='pick up', time=15.400000000000007)
# TimePoint(taxi_id=4, name='drop off', time=15.433333333333346)
# TimePoint(taxi_id=4, name='pick up', time=15.46666666666668)
# TimePoint(taxi_id=2, name='pick up', time=15.500000000000005)
# TimePoint(taxi_id=2, name='drop off', time=15.500000000000005)
# TimePoint(taxi_id=7, name='drop off', time=15.516666666666676)
# TimePoint(taxi_id=7, name='pick up', time=15.55000000000001)
# TimePoint(taxi_id=8, name='drop off', time=15.566666666666666)
# TimePoint(taxi_id=3, name='drop off', time=15.600000000000001)
# TimePoint(taxi_id=5, name='drop off', time=15.616666666666672)
# TimePoint(taxi_id=4, name='drop off', time=15.650000000000013)
# TimePoint(taxi_id=4, name='pick up', time=15.66666666666668)
# TimePoint(taxi_id=3, name='pick up', time=15.683333333333335)
# TimePoint(taxi_id=5, name='pick up', time=15.700000000000006)
# TimePoint(taxi_id=1, name='drop off', time=15.700000000000008)
# TimePoint(taxi_id=1, name='pick up', time=15.716666666666676)
# TimePoint(taxi_id=8, name='pick up', time=15.733333333333333)
# TimePoint(taxi_id=2, name='drop off', time=15.750000000000005)
# TimePoint(taxi_id=7, name='drop off', time=15.766666666666676)
# TimePoint(taxi_id=2, name='pick up', time=15.783333333333339)
# TimePoint(taxi_id=7, name='pick up', time=15.80000000000001)
# TimePoint(taxi_id=6, name='drop off', time=15.816666666666668)
# TimePoint(taxi_id=3, name='drop off', time=15.900000000000002)
# TimePoint(taxi_id=6, name='pick up', time=15.950000000000001)
# TimePoint(taxi_id=2, name='drop off', time=15.950000000000005)
# TimePoint(taxi_id=3, name='pick up', time=15.966666666666669)
# TimePoint(taxi_id=2, name='pick up', time=15.966666666666672)
# TimePoint(taxi_id=5, name='drop off', time=15.966666666666674)
# TimePoint(taxi_id=1, name='drop off', time=15.983333333333343)
# TimePoint(taxi_id=0, name='start shift', time=16)
# TimePoint(taxi_id=5, name='pick up', time=16.000000000000007)
# TimePoint(taxi_id=7, name='drop off', time=16.00000000000001)
# TimePoint(taxi_id=4, name='drop off', time=16.000000000000014)
# TimePoint(taxi_id=1, name='pick up', time=16.033333333333342)
# TimePoint(taxi_id=7, name='pick up', time=16.033333333333346)
# TimePoint(taxi_id=4, name='pick up', time=16.03333333333335)
# TimePoint(taxi_id=1, name='drop off', time=16.216666666666676)
# TimePoint(taxi_id=3, name='drop off', time=16.233333333333334)
# TimePoint(taxi_id=5, name='drop off', time=16.23333333333334)
# TimePoint(taxi_id=3, name='pick up', time=16.25)
# TimePoint(taxi_id=1, name='pick up', time=16.266666666666676)
# TimePoint(taxi_id=2, name='drop off', time=16.28333333333334)
# TimePoint(taxi_id=5, name='pick up', time=16.283333333333342)
# TimePoint(taxi_id=4, name='drop off', time=16.28333333333335)
# TimePoint(taxi_id=7, name='drop off', time=16.31666666666668)
# TimePoint(taxi_id=2, name='pick up', time=16.33333333333334)
# TimePoint(taxi_id=4, name='pick up', time=16.33333333333335)
# TimePoint(taxi_id=7, name='pick up', time=16.36666666666668)
# TimePoint(taxi_id=1, name='drop off', time=16.433333333333344)
# TimePoint(taxi_id=1, name='pick up', time=16.45000000000001)
# TimePoint(taxi_id=2, name='drop off', time=16.500000000000007)
# TimePoint(taxi_id=2, name='pick up', time=16.516666666666673)
# TimePoint(taxi_id=8, name='drop off', time=16.53333333333333)
# TimePoint(taxi_id=4, name='drop off', time=16.53333333333335)
# TimePoint(taxi_id=5, name='drop off', time=16.566666666666677)
# TimePoint(taxi_id=3, name='drop off', time=16.583333333333332)
# TimePoint(taxi_id=5, name='pick up', time=16.600000000000012)
# TimePoint(taxi_id=4, name='pick up', time=16.600000000000016)
# TimePoint(taxi_id=3, name='pick up', time=16.616666666666667)
# TimePoint(taxi_id=7, name='drop off', time=16.61666666666668)
# TimePoint(taxi_id=1, name='drop off', time=16.633333333333344)
# TimePoint(taxi_id=7, name='end_shift', time=16.633333333333347)
# TimePoint(taxi_id=8, name='pick up', time=16.666666666666664)
# TimePoint(taxi_id=2, name='drop off', time=16.700000000000006)
# TimePoint(taxi_id=1, name='pick up', time=16.70000000000001)
# TimePoint(taxi_id=2, name='pick up', time=16.716666666666672)
# TimePoint(taxi_id=4, name='drop off', time=16.716666666666683)
# TimePoint(taxi_id=4, name='pick up', time=16.766666666666683)
# TimePoint(taxi_id=3, name='drop off', time=16.816666666666666)
# TimePoint(taxi_id=1, name='drop off', time=16.833333333333343)
# TimePoint(taxi_id=3, name='pick up', time=16.866666666666667)
# TimePoint(taxi_id=5, name='drop off', time=16.866666666666678)
# TimePoint(taxi_id=1, name='pick up', time=16.883333333333344)
# TimePoint(taxi_id=5, name='pick up', time=16.883333333333344)
# TimePoint(taxi_id=4, name='drop off', time=16.916666666666682)
# TimePoint(taxi_id=4, name='pick up', time=16.950000000000017)
# TimePoint(taxi_id=2, name='drop off', time=16.983333333333338)
# TimePoint(taxi_id=6, name='drop off', time=17.0)
# TimePoint(taxi_id=3, name='drop off', time=17.05)
# TimePoint(taxi_id=2, name='end_shift', time=17.066666666666674)
# TimePoint(taxi_id=5, name='drop off', time=17.066666666666677)
# TimePoint(taxi_id=5, name='pick up', time=17.083333333333343)
# TimePoint(taxi_id=6, name='pick up', time=17.1)
# TimePoint(taxi_id=3, name='pick up', time=17.116666666666667)
# TimePoint(taxi_id=1, name='drop off', time=17.116666666666678)
# TimePoint(taxi_id=4, name='drop off', time=17.13333333333335)
# TimePoint(taxi_id=1, name='end_shift', time=17.183333333333344)
# TimePoint(taxi_id=4, name='end_shift', time=17.200000000000017)
# TimePoint(taxi_id=8, name='drop off', time=17.23333333333333)
# TimePoint(taxi_id=5, name='pick up', time=17.25000000000001)
# TimePoint(taxi_id=5, name='drop off', time=17.25000000000001)
# TimePoint(taxi_id=8, name='pick up', time=17.349999999999998)
# TimePoint(taxi_id=5, name='drop off', time=17.383333333333344)
# TimePoint(taxi_id=3, name='drop off', time=17.433333333333334)
# TimePoint(taxi_id=3, name='pick up', time=17.483333333333334)
# TimePoint(taxi_id=5, name='pick up', time=17.50000000000001)
# TimePoint(taxi_id=5, name='drop off', time=17.65000000000001)
# TimePoint(taxi_id=3, name='drop off', time=17.666666666666668)
# TimePoint(taxi_id=3, name='pick up', time=17.683333333333334)
# TimePoint(taxi_id=5, name='pick up', time=17.70000000000001)
# TimePoint(taxi_id=6, name='drop off', time=17.85)
# TimePoint(taxi_id=6, name='pick up', time=17.950000000000003)
# TimePoint(taxi_id=3, name='drop off', time=18.0)
# TimePoint(taxi_id=5, name='pick up', time=18.00000000000001)
# TimePoint(taxi_id=5, name='drop off', time=18.00000000000001)
# TimePoint(taxi_id=3, name='pick up', time=18.05)
# TimePoint(taxi_id=5, name='drop off', time=18.16666666666668)
# TimePoint(taxi_id=5, name='pick up', time=18.200000000000014)
# TimePoint(taxi_id=8, name='drop off', time=18.216666666666665)
# TimePoint(taxi_id=3, name='drop off', time=18.283333333333335)
# TimePoint(taxi_id=3, name='pick up', time=18.3)
# TimePoint(taxi_id=8, name='pick up', time=18.366666666666664)
# TimePoint(taxi_id=5, name='drop off', time=18.433333333333348)
# TimePoint(taxi_id=5, name='pick up', time=18.433333333333348)
# TimePoint(taxi_id=3, name='drop off', time=18.533333333333335)
# TimePoint(taxi_id=3, name='pick up', time=18.56666666666667)
# TimePoint(taxi_id=5, name='drop off', time=18.61666666666668)
# TimePoint(taxi_id=5, name='pick up', time=18.683333333333348)
# TimePoint(taxi_id=3, name='drop off', time=18.750000000000004)
# TimePoint(taxi_id=6, name='drop off', time=18.800000000000004)
# TimePoint(taxi_id=3, name='pick up', time=18.81666666666667)
# TimePoint(taxi_id=5, name='drop off', time=18.916666666666682)
# TimePoint(taxi_id=3, name='drop off', time=18.950000000000003)
# TimePoint(taxi_id=3, name='pick up', time=18.983333333333338)
# TimePoint(taxi_id=5, name='pick up', time=18.98333333333335)
# TimePoint(taxi_id=8, name='drop off', time=19.016666666666662)
# TimePoint(taxi_id=6, name='end_shift', time=19.01666666666667)
# TimePoint(taxi_id=5, name='drop off', time=19.150000000000016)
# TimePoint(taxi_id=8, name='pick up', time=19.16666666666666)
# TimePoint(taxi_id=3, name='drop off', time=19.16666666666667)
# TimePoint(taxi_id=5, name='pick up', time=19.166666666666682)
# TimePoint(taxi_id=3, name='pick up', time=19.216666666666672)
# TimePoint(taxi_id=5, name='drop off', time=19.36666666666668)
# TimePoint(taxi_id=5, name='pick up', time=19.416666666666682)
# TimePoint(taxi_id=3, name='drop off', time=19.500000000000007)
# TimePoint(taxi_id=5, name='drop off', time=19.53333333333335)
# TimePoint(taxi_id=3, name='end_shift', time=19.566666666666674)
# TimePoint(taxi_id=5, name='pick up', time=19.566666666666684)
# TimePoint(taxi_id=5, name='drop off', time=19.78333333333335)
# TimePoint(taxi_id=5, name='pick up', time=19.83333333333335)
# TimePoint(taxi_id=8, name='drop off', time=19.949999999999996)
# TimePoint(taxi_id=0, name='pick up', time=20)
# TimePoint(taxi_id=5, name='drop off', time=20.03333333333335)
# TimePoint(taxi_id=5, name='pick up', time=20.066666666666684)
# TimePoint(taxi_id=8, name='end_shift', time=20.199999999999996)
# TimePoint(taxi_id=5, name='drop off', time=20.216666666666683)
# TimePoint(taxi_id=5, name='end_shift', time=20.250000000000014)
# TimePoint(taxi_id=0, name='drop off', time=20.483333333333334)
# TimePoint(taxi_id=0, name='pick up', time=20.566666666666666)
# TimePoint(taxi_id=0, name='drop off', time=20.933333333333334)
# TimePoint(taxi_id=0, name='pick up', time=21.05)
# TimePoint(taxi_id=0, name='drop off', time=21.45)
# TimePoint(taxi_id=0, name='pick up', time=21.566666666666666)
# TimePoint(taxi_id=0, name='drop off', time=21.983333333333334)
# TimePoint(taxi_id=0, name='pick up', time=22.066666666666666)
# TimePoint(taxi_id=0, name='drop off', time=22.433333333333334)
# TimePoint(taxi_id=0, name='pick up', time=22.46666666666667)
# TimePoint(taxi_id=0, name='drop off', time=22.866666666666667)
# TimePoint(taxi_id=0, name='pick up', time=22.95)
# TimePoint(taxi_id=0, name='drop off', time=23.45)
# TimePoint(taxi_id=0, name='pick up', time=23.55)
# TimePoint(taxi_id=0, name='drop off', time=24.0)
